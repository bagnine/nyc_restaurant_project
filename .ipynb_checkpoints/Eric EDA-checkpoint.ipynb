# %%
import pandas as pd
import numpy as np

# %%
df_open = pd.read_csv('openrest.csv')

# %%
df_open.head()
# Out:
#    Unnamed: 0                      id                                alias  \
# 0           0  LWHHNai3yu6ovrf4Bcepjg  birria-landia-williamsburg-brooklyn
# 1           1  ETgJqJHV7BW6pIr9Ox74sA                      amélie-new-york
# 2           2  B3_K2kUVbYOU0VaLcj_LTw                thai-villa-new-york-2
# 3           3  Ms3CAGddVbgetiQrpzqxPQ        hometown-bar-b-que-brooklyn-3
# 4           4  0CjK3esfpFcxIopebzjFxA             joes-shanghai-new-york-2
#
#                          name  \
# 0  Birria Landia Williamsburg
# 1                      Amélie
# 2                  Thai Villa
# 3          Hometown Bar-B-Que
# 4              Joe's Shanghai
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/9d2Uad...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVu...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/oELHjg...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/a5YpbH...      False
# ...

# %%
df_open.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 19 columns):
# Unnamed: 0            2500 non-null int64
# id                    2500 non-null object
# alias                 2500 non-null object
# name                  2500 non-null object
# image_url             2500 non-null object
# is_closed             2500 non-null bool
# url                   2500 non-null object
# review_count          2500 non-null int64
# categories            2500 non-null object
# rating                2500 non-null float64
# coordinates           2500 non-null object
# transactions          2500 non-null object
# location              2500 non-null object
# phone                 2350 non-null float64
# display_phone         2350 non-null object
# distance              2500 non-null float64
# price                 2050 non-null object
# permanently closed    2500 non-null int64
# outdoor_seating       2500 non-null int64
# ...

# %%
df_closed = pd.read_csv('closed.csv')

# %%
df_closed.head()
# Out:
#    Unnamed: 0                     alias  \
# 0           0         the-well-brooklyn
# 1           0       trophy-bar-brooklyn
# 2           0           samesa-brooklyn
# 3           0           pearls-brooklyn
# 4           0  maison-premiere-brooklyn
#
#                                           categories  \
# 0  [{'alias': 'beergardens', 'title': 'Beer Garde...
# 1  [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# 2  [{'alias': 'eventplanning', 'title': 'Party & ...
# 3  [{'alias': 'caribbean', 'title': 'Caribbean'},...
# 4  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 40.7084722, 'longitude': -73.9378...  (347) 338-3612
# 1    {'latitude': 40.707908, 'longitude': -73.95565}  (347) 227-8515
# 2  {'latitude': 40.7116966247559, 'longitude': -7...  (718) 599-1154
# 3  {'latitude': 40.7180814, 'longitude': -73.956634}             NaN
# ...

# %%
df_closed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 19 columns):
# Unnamed: 0            190 non-null int64
# alias                 190 non-null object
# categories            190 non-null object
# coordinates           190 non-null object
# display_phone         171 non-null object
# distance              190 non-null float64
# id                    190 non-null object
# image_url             190 non-null object
# is_closed             190 non-null bool
# location              190 non-null object
# name                  190 non-null object
# phone                 171 non-null float64
# price                 176 non-null object
# rating                190 non-null float64
# review_count          190 non-null int64
# transactions          190 non-null object
# url                   190 non-null object
# permanently closed    190 non-null int64
# outdoor_seating       190 non-null int64
# dtypes: bool(1), float64(3), int64(4), object(11)
# ...

# %% [markdown]
# ## Cleaning price column
# #### converting dollar sign to categorical numeric variable

# %%
df_open['price'].value_counts()
# Out:
# $$      1750
# $$$      250
# $$$$      50
# Name: price, dtype: int64

# %%
df_open.isna().sum()
# Out:
# Unnamed: 0              0
# id                      0
# alias                   0
# name                    0
# image_url               0
# is_closed               0
# url                     0
# review_count            0
# categories              0
# rating                  0
# coordinates             0
# transactions            0
# location                0
# phone                 150
# display_phone         150
# distance                0
# price                 450
# permanently closed      0
# outdoor_seating         0
# dtype: int64

# %%
cond = [df_open['price'] == '$$',
        df_open['price'] == '$$$',
        df_open['price'] == '$$$$'
       ]
choice = ['two','three','four']
df_open['price_cat'] = np.select(cond, choice,default='missing')
df_open.head()
# Out:
#    Unnamed: 0                      id                                alias  \
# 0           0  LWHHNai3yu6ovrf4Bcepjg  birria-landia-williamsburg-brooklyn
# 1           1  ETgJqJHV7BW6pIr9Ox74sA                      amélie-new-york
# 2           2  B3_K2kUVbYOU0VaLcj_LTw                thai-villa-new-york-2
# 3           3  Ms3CAGddVbgetiQrpzqxPQ        hometown-bar-b-que-brooklyn-3
# 4           4  0CjK3esfpFcxIopebzjFxA             joes-shanghai-new-york-2
#
#                          name  \
# 0  Birria Landia Williamsburg
# 1                      Amélie
# 2                  Thai Villa
# 3          Hometown Bar-B-Que
# 4              Joe's Shanghai
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/9d2Uad...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVu...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/oELHjg...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/a5YpbH...      False
# ...

# %%
df_open['price_cat'].value_counts()
# Out:
# two        1750
# missing     450
# three       250
# four         50
# Name: price_cat, dtype: int64

# %%
# df_open2 = pd.get_dummies(data = df_open['price'])

# %% [markdown]
# ## Breaking out transactions column

# %%
import ast

# %%
df_open['transactions'] = df_open['transactions'].map(lambda x: ast.literal_eval(x))

# %%
df_open['transactions'][1]
# Out:
# ['restaurant_reservation', 'delivery', 'pickup']

# %%
df_open['delivery'] = df_open['transactions'].apply(lambda x: 1 if 'delivery' in x else 0)
df_open['restaurant_reservation'] = df_open['transactions'].apply(lambda x: 1 if 'restaurant_reservation' in x else 0)
df_open['pickup'] = df_open['transactions'].apply(lambda x: 1 if 'pickup' in x else 0)

# %%
df_open.head(5)
# Out:
#    Unnamed: 0                      id                                alias  \
# 0           0  LWHHNai3yu6ovrf4Bcepjg  birria-landia-williamsburg-brooklyn
# 1           1  ETgJqJHV7BW6pIr9Ox74sA                      amélie-new-york
# 2           2  B3_K2kUVbYOU0VaLcj_LTw                thai-villa-new-york-2
# 3           3  Ms3CAGddVbgetiQrpzqxPQ        hometown-bar-b-que-brooklyn-3
# 4           4  0CjK3esfpFcxIopebzjFxA             joes-shanghai-new-york-2
#
#                          name  \
# 0  Birria Landia Williamsburg
# 1                      Amélie
# 2                  Thai Villa
# 3          Hometown Bar-B-Que
# 4              Joe's Shanghai
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/9d2Uad...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVu...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/oELHjg...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/a5YpbH...      False
# ...

# %%
df_open['delivery'].value_counts()
# Out:
# 1    1850
# 0     650
# Name: delivery, dtype: int64

# %%
df_open['restaurant_reservation'].value_counts()
# Out:
# 0    2050
# 1     450
# Name: restaurant_reservation, dtype: int64

# %%
df_open['pickup'].value_counts()
# Out:
# 1    1800
# 0     700
# Name: pickup, dtype: int64

# %% [markdown]
# ## Cleaning Price and transactions in closed df

# %%
df_closed.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 19 columns):
# Unnamed: 0            190 non-null int64
# alias                 190 non-null object
# categories            190 non-null object
# coordinates           190 non-null object
# display_phone         171 non-null object
# distance              190 non-null float64
# id                    190 non-null object
# image_url             190 non-null object
# is_closed             190 non-null bool
# location              190 non-null object
# name                  190 non-null object
# phone                 171 non-null float64
# price                 176 non-null object
# rating                190 non-null float64
# review_count          190 non-null int64
# transactions          190 non-null object
# url                   190 non-null object
# permanently closed    190 non-null int64
# outdoor_seating       190 non-null int64
# dtypes: bool(1), float64(3), int64(4), object(11)
# ...

# %%
df_closed.head()
# Out:
#    Unnamed: 0                     alias  \
# 0           0         the-well-brooklyn
# 1           0       trophy-bar-brooklyn
# 2           0           samesa-brooklyn
# 3           0           pearls-brooklyn
# 4           0  maison-premiere-brooklyn
#
#                                           categories  \
# 0  [{'alias': 'beergardens', 'title': 'Beer Garde...
# 1  [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# 2  [{'alias': 'eventplanning', 'title': 'Party & ...
# 3  [{'alias': 'caribbean', 'title': 'Caribbean'},...
# 4  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 40.7084722, 'longitude': -73.9378...  (347) 338-3612
# 1    {'latitude': 40.707908, 'longitude': -73.95565}  (347) 227-8515
# 2  {'latitude': 40.7116966247559, 'longitude': -7...  (718) 599-1154
# 3  {'latitude': 40.7180814, 'longitude': -73.956634}             NaN
# ...

# %%
df_closed.isna().sum()
# Out:
# Unnamed: 0             0
# alias                  0
# categories             0
# coordinates            0
# display_phone         19
# distance               0
# id                     0
# image_url              0
# is_closed              0
# location               0
# name                   0
# phone                 19
# price                 14
# rating                 0
# review_count           0
# transactions           0
# url                    0
# permanently closed     0
# outdoor_seating        0
# dtype: int64

# %%
df_closed['price'].value_counts()
# Out:
# $$      126
# $        24
# $$$      23
# $$$$      3
# Name: price, dtype: int64

# %%
cond = [df_closed['price'] == '$',
        df_closed['price'] == '$$',
        df_closed['price'] == '$$$',
        df_closed['price'] == '$$$$'
       ]
choice = ['one','two','three','four']
df_closed['price_cat'] = np.select(cond, choice,default='missing')
df_closed.head()
# Out:
#    Unnamed: 0                     alias  \
# 0           0         the-well-brooklyn
# 1           0       trophy-bar-brooklyn
# 2           0           samesa-brooklyn
# 3           0           pearls-brooklyn
# 4           0  maison-premiere-brooklyn
#
#                                           categories  \
# 0  [{'alias': 'beergardens', 'title': 'Beer Garde...
# 1  [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# 2  [{'alias': 'eventplanning', 'title': 'Party & ...
# 3  [{'alias': 'caribbean', 'title': 'Caribbean'},...
# 4  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 40.7084722, 'longitude': -73.9378...  (347) 338-3612
# 1    {'latitude': 40.707908, 'longitude': -73.95565}  (347) 227-8515
# 2  {'latitude': 40.7116966247559, 'longitude': -7...  (718) 599-1154
# 3  {'latitude': 40.7180814, 'longitude': -73.956634}             NaN
# ...

# %%
df_closed['price_cat'].value_counts()
# Out:
# two        126
# one         24
# three       23
# missing     14
# four         3
# Name: price_cat, dtype: int64

# %%
df_closed['transactions'] = df_closed['transactions'].map(lambda x: ast.literal_eval(x))

# %%
df_closed['delivery'] = df_closed['transactions'].apply(lambda x: 1 if 'delivery' in x else 0)
df_closed['restaurant_reservation'] = df_closed['transactions'].apply(lambda x: 1 if 'restaurant_reservation' in x else 0)
df_closed['pickup'] = df_closed['transactions'].apply(lambda x: 1 if 'pickup' in x else 0)

# %%
print(df_closed['delivery'].value_counts())
print(df_closed['restaurant_reservation'].value_counts())
print(df_closed['pickup'].value_counts())
# Out:
# 1    96
# 0    94
# Name: delivery, dtype: int64
# 0    186
# 1      4
# Name: restaurant_reservation, dtype: int64
# 1    98
# 0    92
# Name: pickup, dtype: int64

# %% [markdown]
# ## Pull out zip from the location column

# %%
df_open['location'] = df_open['location'].map(lambda x: ast.literal_eval(x))

# %%
df_open['location']
# Out:
# 0       {'address1': '495 Metropolian Ave', 'address2'...
# 1       {'address1': '22 W 8th St', 'address2': '', 'a...
# 2       {'address1': '5 E 19th St', 'address2': 'G Flo...
# 3       {'address1': '454 Van Brunt St', 'address2': '...
# 4       {'address1': '46 Bowery St', 'address2': '', '...
#                               ...
# 2495    {'address1': '375 S End Ave', 'address2': '', ...
# 2496    {'address1': '239 5th Ave', 'address2': '', 'a...
# 2497    {'address1': '132 West 47th St', 'address2': N...
# 2498    {'address1': '171 Spring St', 'address2': '', ...
# 2499    {'address1': '233 West St', 'address2': '', 'a...
# Name: location, Length: 2500, dtype: object

# %%
df_open['location'][0]
# Out:
# {'address1': '495 Metropolian Ave',
#  'address2': '',
#  'address3': None,
#  'city': 'Brooklyn',
#  'zip_code': '11211',
#  'country': 'US',
#  'state': 'NY',
#  'display_address': ['495 Metropolian Ave', 'Brooklyn, NY 11211']}

# %%
df_open['location'][0]['zip_code']
# Out:
# '11211'

# %%
df_open['zip_code'] = df_open['location'].apply(lambda x: x['zip_code'])

# %% [markdown]
# #### Repeating for closed df

# %%
df_closed['location'] = df_closed['location'].map(lambda x: ast.literal_eval(x))

# %%
df_closed['zip_code'] = df_closed['location'].apply(lambda x: x['zip_code'])

# %% [markdown]
# ## Pulling out lat and long

# %%
df_open['coordinates'] = df_open['coordinates'].map(lambda x: ast.literal_eval(x))

# %%
df_open['coordinates']
# Out:
# 0       {'latitude': 40.7141949, 'longitude': -73.9520...
# 1           {'latitude': 40.7327, 'longitude': -73.99766}
# 2          {'latitude': 40.73902, 'longitude': -73.99065}
# 3          {'latitude': 40.67486, 'longitude': -74.01602}
# 4       {'latitude': 40.7156608, 'longitude': -73.9967...
#                               ...
# 2495    {'latitude': 40.7112882252543, 'longitude': -7...
# 2496       {'latitude': 40.67519, 'longitude': -73.98116}
# 2497     {'latitude': 40.758417, 'longitude': -73.983301}
# 2498    {'latitude': 40.724912, 'longitude': -74.0021299}
# 2499    {'latitude': 40.7205582, 'longitude': -74.0118...
# Name: coordinates, Length: 2500, dtype: object

# %%
df_open['latitude'] = df_open['coordinates'].map(lambda x: x['latitude'])
df_open['longitude'] = df_open['coordinates'].map(lambda x: x['longitude'])

# %%
df_closed['coordinates'] = df_closed['coordinates'].map(lambda x: ast.literal_eval(x))

# %%
df_closed['latitude'] = df_closed['coordinates'].map(lambda x: x['latitude'])
df_closed['longitude'] = df_closed['coordinates'].map(lambda x: x['longitude'])
